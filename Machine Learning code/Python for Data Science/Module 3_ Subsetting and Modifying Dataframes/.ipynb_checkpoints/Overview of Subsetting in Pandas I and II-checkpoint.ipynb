# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Overview of Subsetting in Pandas 📍 📍</h1></center>
#
#
#
# ---
#
# ### `TABLE OF CONTENTS`
#
# - What is an index?
# - How to subset first N rows based on their position index?
# - Can we change the index?
# - Will the index be always numeric?
# - How to subset the data based on a label of the index?
# - Can we reset the index?
# - How to subset the data based on a value of a column?
#
# ---
#
#
# #### `READ THE DATA`
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.

# %%
# import the pandas library
import pandas as pd

# %%
# read the big mart sales data
data = pd.read_csv('datasets/big_mart_sales.csv')

# %% [markdown]
# <div class="mark">
#
# <h4>WHAT IS INDEX?</h4>
#
# ![](index.png)
#
# -  You can see the index object by `DataFrame.index`.</div><i class="fa fa-lightbulb-o "></i>

# %% [markdown]
# <img src="img/1.png" alt="indexing" width=70%>

# %%
# index of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %% [markdown]
# ***So, In this case, we have the numeric index value start from the 0 and ends at 8523.***

# %%
# no. of rows and columns in the data
data.shape
# Out:
# (8523, 12)

# %%
# column index
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# #### `HOW TO SUBSET FIRST 'N' ROWS BASED ON THEIR POSITION INDEX?`

# %%
# view the top rows of the data
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %% [markdown]
# ---
#
# ### `CAN WE CHANGE THE INDEX?`
#
# ---
#
# ***The answer is `Yes`. We can change the index. Let's see how?***
#
# ---

# %% [markdown]
# #### Create a random list of 8523 numbers and set it as the index
# ---

# %%
# create random list
import random
random_list = [random.randint(1, 8523) for i in range(8523)]

# %%
random_list
# Out:
# [8079,
#  6593,
#  7266,
#  8164,
#  5999,
#  1841,
#  1485,
#  3599,
#  1548,
#  1628,
#  6335,
#  3143,
#  3883,
#  2795,
#  5794,
#  6444,
#  719,
#  5378,
#  5480,
#  4318,
#  5899,
#  4282,
#  2332,
#  6147,
#  7952,
#  7370,
#  3024,
#  6557,
#  8453,
#  1608,
#  2868,
#  501,
#  7287,
#  8481,
#  972,
#  2040,
#  4863,
#  1800,
#  1704,
#  4142,
#  5095,
#  1700,
#  2918,
#  7113,
#  3440,
#  4042,
#  4617,
#  3128,
#  2714,
#  2154,
#  5232,
#  4039,
#  6871,
#  613,
#  6292,
#  8222,
#  1884,
#  229,
#  7557,
#  8073,
#  4162,
#  262,
#  3375,
#  3807,
#  6776,
#  7842,
#  6282,
#  4887,
#  7281,
#  1367,
#  4394,
#  3536,
#  5894,
#  5330,
#  3062,
#  6813,
#  5927,
#  2159,
#  6497,
#  1559,
#  3186,
#  124,
#  6427,
#  4233,
#  4264,
#  7795,
#  5465,
#  4504,
#  2276,
#  1674,
#  1024,
#  987,
#  7450,
#  3129,
#  5061,
#  7022,
#  291,
#  483,
#  4722,
#  2088,
#  2148,
#  5159,
#  2475,
#  5466,
#  6417,
#  3145,
#  2137,
#  4583,
#  3418,
#  4488,
#  4743,
#  2677,
# ...

# %%
len(random_list)
# Out:
# 8523

# %% [markdown]
# #### set the index of rows

# %%
# set the index
data.index = random_list

# %%
data.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8079           FDA15         9.30          Low Fat         0.016047
# 6593           DRC01         5.92          Regular         0.019278
# 7266           FDN15        17.50          Low Fat         0.016760
# 8164           FDX07        19.20          Regular         0.000000
# 5999           NCD19         8.93          Low Fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 8079                  Dairy  249.8092            OUT049
# 6593            Soft Drinks   48.2692            OUT018
# 7266                   Meat  141.6180            OUT049
# 8164  Fruits and Vegetables  182.0950            OUT010
# 5999              Household   53.8614            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8079                       1999      Medium               Tier 1
# 6593                       2009      Medium               Tier 3
# ...

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8079           FDA15        9.300          Low Fat         0.016047
# 6593           DRC01        5.920          Regular         0.019278
# 7266           FDN15       17.500          Low Fat         0.016760
# 8164           FDX07       19.200          Regular         0.000000
# 5999           NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 2783           FDF22        6.865          Low Fat         0.056783
# 4274           FDS36        8.380          Regular         0.046982
# 3365           NCJ29       10.600          Low Fat         0.035186
# 4263           FDN46        7.210          Regular         0.145221
# 7409           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 8079                  Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ## Set another column of the dataframe as the index. We will use the set_index function.

# %% [markdown]
# You can read more about here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html'***
#
# ---

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
#  ##### <span class="mark">change the index of the dataframe</span>
#
# ***drop=True is used to drop the column that's set as index.It is very helpful in the case of duplicate columns.***
#
# ***inplace=True is used to make changes in the original dataframe.***

# %% [markdown]
# #### What if drop = False

# %%
data = pd.read_csv("datasets/big_mart_sales.csv")

# %%
data.set_index('Outlet_Establishment_Year', drop=False, inplace=True)
data.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15         9.30          Low Fat
# 2009                                DRC01         5.92          Regular
# 1999                                FDN15        17.50          Low Fat
# 1998                                FDX07        19.20          Regular
# 1987                                NCD19         8.93          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
#
# ...

# %% [markdown]
# ###### <span class="mark">As we see above establishment year is not drop from columns , so there area two same columns. In this case, drop=True comes to help.</span>

# %%
data.set_index('Outlet_Establishment_Year', drop=True,inplace = True)
data.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15         9.30          Low Fat
# 2009                                DRC01         5.92          Regular
# 1999                                FDN15        17.50          Low Fat
# 1998                                FDX07        19.20          Regular
# 1987                                NCD19         8.93          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
#
# ...

# %% [markdown]
# ###### <span class="burk">If inplace = False then index is not updated to dataframe. if you want to change dataframe inplace = True is must. If inplace= False then dataframe index are again default to 0,1,2,3,..</span>

# %%
data = pd.read_csv("datasets/big_mart_sales.csv")

# %%
data.set_index('Outlet_Establishment_Year', drop=True, inplace=False)
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15        9.300          Low Fat
# 2009                                DRC01        5.920          Regular
# 1999                                FDN15       17.500          Low Fat
# 1998                                FDX07       19.200          Regular
# 1987                                NCD19        8.930          Low Fat
# ...                                   ...          ...              ...
# 1987                                FDF22        6.865          Low Fat
# 2002                                FDS36        8.380          Regular
# 2004                                NCJ29       10.600          Low Fat
# 2009                                FDN46        7.210          Regular
# 1997                                DRG01       14.800          Low Fat
#
# ...

# %% [markdown]
# ###### Since ```inplace = False``` after some time changes are gone and dataframe is  not updated and index are set to default.

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %% [markdown]
# #### Use of inplace parameter.

# %%
data = pd.read_csv("datasets/big_mart_sales.csv")

data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)

# %% [markdown]
# <span class="mark">Now, establishment year column dropped and index also updated.</span>

# %%
data.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15         9.30          Low Fat
# 2009                                DRC01         5.92          Regular
# 1999                                FDN15        17.50          Low Fat
# 1998                                FDX07        19.20          Regular
# 1987                                NCD19         8.93          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
#
# ...

# %% [markdown]
# ##### So drop and inplace parameters are very helpful.

# %% [markdown]
# <span class="mark">
#
# <b>When you use ```inplace = True``` parameter, then pandas create a new datafrane with changes you made and  returns a new Dataframe to you.</b>
#
# <b>Therefore, It is advised, that when you use ```inplace = True```, Save a changed dataframe to a new variable. So, original data are not changed and remain safe.</b>
#
#
# </span>

# %%
data = pd.read_csv("datasets/big_mart_sales.csv")

# %%
# 1. change the index of the dataframe
# 2. drop=True is used to drop the column that's set as index
# 3. inplace=True is used to make changes in the original dataframe
# data = pd.read_csv('datasets/big_mart_sales.csv')

new_data = data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)

# %%
new_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10384/4269257853.py in <module>
# ----> 1 new_data.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %% [markdown]
# <b>If we store it in  a new variable then set the ```inplace = False```. </b>

# %%
data = pd.read_csv("datasets/big_mart_sales.csv")

# %%
# 1. change the index of the dataframe
# 2. drop=True is used to drop the column that's set as index
# 3. inplace=True is used to make changes in the original dataframe
# data = pd.read_csv('datasets/big_mart_sales.csv')

new_data = data.set_index('Outlet_Establishment_Year', drop=True, inplace=False)

# %%
new_data.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15         9.30          Low Fat
# 2009                                DRC01         5.92          Regular
# 1999                                FDN15        17.50          Low Fat
# 1998                                FDX07        19.20          Regular
# 1987                                NCD19         8.93          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
#
# ...

# %%
# example of a label based index
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
new_data.index
# Out:
# Int64Index([1999, 2009, 1999, 1998, 1987, 2009, 1987, 1985, 2002, 2007,
#             ...
#             2004, 2002, 2009, 2009, 1997, 1987, 2002, 2004, 2009, 1997],
#            dtype='int64', name='Outlet_Establishment_Year', length=8523)

# %%
# original data

data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %% [markdown]
# ---
#
# ## `WILL THE INDEX BE ALWAYS NUMERIC?`
#
# ---
#
#
# ***No, We can also have categorical variables as the index of a dataframe.***
#
# ---

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %%
# reset the index
data.set_index('Item_Identifier', drop= True, inplace=True)

# %%
# view the top rows of the data
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
# index of the data
data.index
# Out:
# Index(['FDA15', 'DRC01', 'FDN15', 'FDX07', 'NCD19', 'FDP36', 'FDO10', 'FDP10',
#        'FDH17', 'FDU28',
#        ...
#        'FDH31', 'FDA01', 'FDH24', 'NCJ19', 'FDF53', 'FDF22', 'FDS36', 'NCJ29',
#        'FDN46', 'DRG01'],
#       dtype='object', name='Item_Identifier', length=8523)

# %% [markdown]
# ---
#
# ## `HOW TO SUBSET THE DATA BASED ON THE LABEL OF THE INDEX?`
#
# <b><span class="mark">We can subset the data based on the label of the index using the loc function.</span></b>
#
#
# ---

# %% [markdown]
# Only get the results of all rows with FDA15 label.

# %%
data.loc['FDA15']
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
# FDA15            250.2092            OUT045                       2002
# ...

# %% [markdown]
# ***What if we want to change the index back to positional?***
#
# ---

# %% [markdown]
# ## `CAN WE RESET THE INDEX?`
#
# <b>Yes, we can reset the index. Let's see how?
# We will use the ```reset_index function```.
#
# You can read more about here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html</b>
#
# ---

# %%
# reset the index
data.reset_index(inplace=True)

# %% [markdown]
# ###### Data are reverse back to it's original form.

# %%
# view the top rows of the data
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ## `HOW TO SUBSET THE DATA BASED ON A VALUE OF A COLUMN?`
#
# ---

# %% [markdown]
# Get only data which item_type is Dairy, Looks similar to the exce's filter feature.

# %%
data[data['Item_Type'] == 'Dairy']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0              FDA15        9.300          Low Fat         0.016047     Dairy
# 11             FDA03       18.500          Regular         0.045464     Dairy
# 19             FDU02       13.350          Low Fat         0.102492     Dairy
# 28             FDE51        5.925          Regular         0.161467     Dairy
# 30             FDV38       19.250          Low Fat         0.170349     Dairy
# ...              ...          ...              ...              ...       ...
# 8424           FDC39        7.405          Low Fat         0.159165     Dairy
# 8447           FDS26       20.350          Low Fat         0.089975     Dairy
# 8448           FDV50       14.300          Low Fat         0.123071     Dairy
# 8457           FDY50        5.800          Low Fat         0.130931     Dairy
# 8512           FDR26       20.700          Low Fat         0.042801     Dairy
#
# ...

# %% [markdown]
# Only data whose Outlet_Location_Type == "Tier 1".

# %%
data[data['Outlet_Location_Type'] == "Tier 1"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 2              FDN15        17.50          Low Fat         0.016760
# 10             FDY07        11.80          Low Fat         0.000000
# 11             FDA03        18.50          Regular         0.045464
# 12             FDX32        15.10          Regular         0.100014
# ...              ...          ...              ...              ...
# 8480           FDQ58          NaN          Low Fat         0.000000
# 8490           FDU44          NaN          Regular         0.102296
# 8492           FDT34         9.30          Low Fat         0.174350
# 8517           FDF53        20.75              reg         0.083607
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ----
#
# ###### `WE WILL SEE HOW TO SUBSET THE DATA BASED ON POSITION, LABEL AND VALUES IN DETAIL`
#
# ---
